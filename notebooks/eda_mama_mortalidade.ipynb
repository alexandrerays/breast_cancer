# %% [markdown]
# ### Libs

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
palette = sns.color_palette("ch:2.5,-.1,dark=.1")

# %% [markdown]
# ### Carrega datasets

# %%
df_sus = pd.read_csv(
    '../data/Banco_Datathon/Banco_Datathon/mama/Mortalidade_Mama_SIM-SUS.csv',
    encoding='ISO-8859-1',
    index_col=0,
    low_memory=True
)

# %%
print(df_sus.shape)
df_sus.head()
# Out:
# (63560, 92)
#     NUMERODO        CODINST  NUMERODV  ORIGEM  TIPOBITO   DTOBITO  HORAOBITO  \
# 9   20001566  MAC1200400001       4.0       1         2  23012014     1000.0
# 16  20001748  MAC1200400001       9.0       1         2   6022014     1555.0
# 27  20001494  MAC1200400001       3.0       1         2  16022014     1830.0
# 28  20001864  MAC1200400001       7.0       1         2  20022014     2225.0
# 30  20001869  MAC1200400001       8.0       1         2  23022014      840.0
#
#           NUMSUS  NATURAL  CODMUNNATU      DTNASC  IDADE  SEXO  RACACOR  \
# 9            NaN    812.0    120010.0  26121961.0    452     2      2.0
# 16           NaN    812.0    120070.0  30091977.0    436     2      4.0
# 27           NaN    812.0    120040.0   4021963.0    451     2      4.0
# 28           NaN    812.0    120050.0  28031969.0    444     2      4.0
# 30  8.980011e+14    812.0    120040.0  10091939.0    474     1      4.0
#
#     ESTCIV  ESC  ESC2010  SERIESCFAL      OCUP  CODMUNRES  LOCOCOR   CODESTAB  \
# 9      NaN  0.0      NaN         NaN       NaN     120040        1  2001586.0
# 16     1.0  2.0      1.0         NaN  999992.0     120017        1  2001586.0
# 27     4.0  0.0      NaN         NaN       NaN     120040        1  2001578.0
# 28     2.0  5.0      4.0         NaN       NaN     120040        1  2001586.0
# 30     2.0  1.0      0.0         NaN  999992.0     120040        1  2001586.0
#
#    ESTABDESCR  CODMUNOCOR  IDADEMAE  ESCMAE  ESCMAE2010  SERIESCMAE  OCUPMAE  \
# 9         NaN      120040       NaN     NaN         NaN         NaN      NaN
# 16        NaN      120040       NaN     NaN         NaN         NaN      NaN
# 27        NaN      120040       NaN     NaN         NaN         NaN      NaN
# 28        NaN      120040       NaN     NaN         NaN         NaN      NaN
# 30        NaN      120040       NaN     NaN         NaN         NaN      NaN
#
#     QTDFILVIVO  QTDFILMORT  GRAVIDEZ  SEMAGESTAC  GESTACAO  PARTO  OBITOPARTO  \
# 9          NaN         NaN       NaN         NaN       NaN    NaN         NaN
# 16         NaN         NaN       NaN         NaN       NaN    NaN         NaN
# 27         NaN         NaN       NaN         NaN       NaN    NaN         NaN
# 28         NaN         NaN       NaN         NaN       NaN    NaN         NaN
# 30         NaN         NaN       NaN         NaN       NaN    NaN         NaN
#
#     PESO  NUMERODN  TPMORTEOCO  OBITOGRAV  OBITOPUERP  ASSISTMED  EXAME  \
# 9    NaN       NaN         NaN        NaN         NaN        NaN    NaN
# 16   NaN       NaN         NaN        NaN         NaN        1.0    NaN
# 27   NaN       NaN         NaN        NaN         NaN        1.0    NaN
# 28   NaN       NaN         8.0        2.0         3.0        1.0    NaN
# 30   NaN       NaN         NaN        NaN         NaN        1.0    NaN
#
#     CIRURGIA  NECROPSIA LINHAA LINHAB LINHAC LINHAD LINHAII  \
# 9        NaN        NaN  *R688  *C780  *C509    NaN     NaN
# 16       NaN        2.0    NaN  *J969  *C793  *C509     NaN
# 27       NaN        2.0  *J969  *J189  *C509    NaN     NaN
# 28       NaN        2.0  *J960  *A419  *J90X  *C795   *C509
# 30       NaN        NaN  *R688  *C509    NaN    NaN     NaN
#
#                CAUSABAS  CB_PRE    CRM  COMUNSVOIM  DTATESTADO  CIRCOBITO  \
# 9   C50- Câncer de mama     NaN   1086         NaN  23012014.0        NaN
# 16  C50- Câncer de mama     NaN   1409         NaN   6022014.0        NaN
# 27  C50- Câncer de mama     NaN  44545         NaN  16022014.0        NaN
# 28  C50- Câncer de mama     NaN   1397         NaN  20022014.0        NaN
# 30  C50- Câncer de mama     NaN   1507         NaN  23022014.0        NaN
#
#     ACIDTRAB  FONTE  NUMEROLOTE TPPOS  DTINVESTIG CAUSABAS_O  DTCADASTRO  \
# 9        NaN    NaN  20140004.0     N         NaN       C509  21022014.0
# 16       NaN    NaN  20140004.0     N         NaN       C509  17022014.0
# 27       NaN    NaN  20140005.0     N         NaN       C509  14032014.0
# 28       NaN    NaN  20140012.0     S  24032014.0       C509  19032014.0
# 30       NaN    NaN  20140006.0     N         NaN       C509  19032014.0
#
#     ATESTANTE STCODIFICA CODIFICADO VERSAOSIST  VERSAOSCB  FONTEINV  \
# 9         1.0          S          S     3.2.00        3.2       NaN
# 16        5.0          S          S     3.2.00        3.2       NaN
# 27        5.0          S          S     3.2.00        3.2       NaN
# 28        5.0          S          S     3.2.00        3.2       8.0
# 30        NaN          S          S     3.2.00        3.2       NaN
#
#      DTRECEBIM                 ATESTADO  DTRECORIGA  CAUSAMAT  ESCMAEAGR1  \
# 9   28022014.0           R688/C780/C509  28022014.0       NaN         NaN
# 16  28022014.0          /J969/C793/C509  28022014.0       NaN         NaN
# 27  25032014.0           J969/J189/C509  25032014.0       NaN         NaN
# 28  13062014.0  J960/A419/J90/C795*C509  31032014.0       NaN         NaN
# 30  31032014.0                R688/C509  31032014.0       NaN         NaN
#
#     ESCFALAGR1  STDOEPIDEM  STDONOVA  DIFDATA  NUDIASOBCO  NUDIASOBIN  \
# 9          NaN         0.0       0.0     36.0         NaN         NaN
# 16        10.0         0.0       0.0     22.0        63.0        63.0
# 27         NaN         0.0       0.0     37.0         NaN         NaN
# 28         7.0         0.0       0.0    113.0        32.0        46.0
# 30         0.0         0.0       0.0     36.0         NaN         NaN
#
#       DTCADINV  TPOBITOCOR    DTCONINV  FONTES  TPRESGINFO TPNIVELINV  \
# 9          NaN         NaN         NaN     NaN         NaN        NaN
# 16  10042014.0         9.0  10042014.0  SSXXXX         NaN          M
# 27         NaN         NaN         NaN     NaN         NaN        NaN
# 28   7042014.0         9.0  24032014.0  SXSXXX         NaN          M
# 30         NaN         NaN         NaN     NaN         NaN        NaN
#
#     NUDIASINF  DTCADINF  MORTEPARTO  DTCONCASO FONTESINF  ALTCAUSA
# 9         NaN       NaN         NaN        NaN   XXXXXXX       NaN
# 16        NaN       NaN         NaN        NaN   XXXXXXX       NaN
# 27        NaN       NaN         NaN        NaN   XXXXXXX       NaN
# 28        NaN       NaN         NaN        NaN   XXXXXXX       NaN
# 30        NaN       NaN         NaN        NaN   XXXXXXX       NaN

# %% [markdown]
# ### Nulos

# %%
null_count = df_sus.isna().sum()
null_percentage = round(100 * (null_count / len(df_sus)), 3)
null_tbl = pd.DataFrame(
    data=[null_count, null_percentage, df_sus.dtypes],
    index=['null_count', 'null_percentage', 'types']).T.sort_values(ascending=False, by='null_percentage'
)

# %%
null_tbl
# Out:
#            null_count null_percentage    types
# ALTCAUSA        63560             100  float64
# IDADEMAE        63560             100  float64
# ESCMAE2010      63560             100  float64
# SERIESCMAE      63560             100  float64
# CAUSAMAT        63560             100  float64
# OCUPMAE         63560             100  float64
# ESCMAEAGR1      63560             100  float64
# QTDFILVIVO      63560             100  float64
# QTDFILMORT      63560             100  float64
# GRAVIDEZ        63560             100  float64
# SEMAGESTAC      63560             100  float64
# GESTACAO        63560             100  float64
# PARTO           63560             100  float64
# PESO            63560             100  float64
# NUMERODN        63560             100  float64
# NUDIASINF       63560             100  float64
# DTCADINF        63560             100  float64
# MORTEPARTO      63560             100  float64
# DTCONCASO       63560             100  float64
# ACIDTRAB        63560             100  float64
# CB_PRE          63560             100  float64
# OBITOPARTO      63559          99.998  float64
# ESCMAE          63559          99.998  float64
# ESTABDESCR      63552          99.987   object
# FONTE           63536          99.962  float64
# CIRCOBITO       63534          99.959  float64
# TPRESGINFO      63440          99.811  float64
# CIRURGIA        63140          99.339  float64
# EXAME           63130          99.323  float64
# COMUNSVOIM      61657          97.006  float64
# NUDIASOBIN      57079          89.803  float64
# SERIESCFAL      54910          86.391  float64
# FONTES          53565          84.275   object
# NUMSUS          52863           83.17  float64
# DTINVESTIG      51823          81.534  float64
# FONTEINV        51599          81.182  float64
# LINHAD          50625          79.649   object
# DTCONINV        50274          79.097  float64
# NUDIASOBCO      50272          79.094  float64
# TPOBITOCOR      50118          78.851  float64
# DTCADINV        50117           78.85  float64
# TPNIVELINV      50115          78.847   object
# FONTESINF       48774          76.737   object
# LINHAII         48347          76.065   object
# TPMORTEOCO      43179          67.934  float64
# OBITOPUERP      43033          67.705  float64
# OBITOGRAV       43027          67.695  float64
# LINHAC          31216          49.113   object
# TPPOS           21073          33.154   object
# NECROPSIA       16614          26.139  float64
# LINHAB          16378          25.768   object
# ASSISTMED       16229          25.533  float64
# CODESTAB         8410          13.232  float64
# OCUP             8250           12.98  float64
# ATESTANTE        5806           9.135  float64
# CODMUNNATU       5404           8.502  float64
# ESC2010          4672           7.351  float64
# ESCFALAGR1       4672           7.351  float64
# NATURAL          4461           7.019  float64
# ESC              3450           5.428  float64
# RACACOR          2424           3.814  float64
# VERSAOSCB        2327           3.661  float64
# LINHAA           2249           3.538   object
# ESTCIV           1783           2.805  float64
# CRM              1402           2.206   object
# HORAOBITO         748           1.177  float64
# DTATESTADO        324            0.51  float64
# DTCADASTRO        216            0.34  float64
# NUMERODV           71           0.112  float64
# CAUSABAS_O         35           0.055   object
# DTRECEBIM          30           0.047  float64
# DTNASC             21           0.033  float64
# VERSAOSIST         19            0.03   object
# STDOEPIDEM         19            0.03  float64
# CODIFICADO         19            0.03   object
# STCODIFICA         19            0.03   object
# NUMEROLOTE         19            0.03  float64
# ATESTADO            7           0.011   object
# DIFDATA             7           0.011  float64
# DTRECORIGA          7           0.011  float64
# STDONOVA            3           0.005  float64
# DTOBITO             0               0    int64
# TIPOBITO            0               0    int64
# ORIGEM              0               0    int64
# CAUSABAS            0               0   object
# IDADE               0               0    int64
# SEXO                0               0    int64
# CODMUNRES           0               0    int64
# LOCOCOR             0               0    int64
# CODMUNOCOR          0               0    int64
# CODINST             0               0   object
# NUMERODO            0               0    int64
